# %%
import pandas as pd
import re

# %%
# turn the whole excel file into csv files thanks to Python

excel_path = 'data/resume/data_resume.xlsx'

# Read the whole files and the associated tabs
xls_tab = pd.read_excel(excel_path, sheet_name=None)

# Assign tab value to different variable
me = xls_tab['Me']
locations = xls_tab['Locations']
experiences = xls_tab['Experiences']
educations = xls_tab['Educations']
contracts = xls_tab['Contracts']
skills = xls_tab['Skills']
companies = xls_tab['Companies']
skill_experiences = xls_tab['Skill_experiences']
degrees = xls_tab['Degrees']
certifications = xls_tab['Certification']
schools = xls_tab['Schools']
leisures = xls_tab['Leisures']
languages = xls_tab['Languages']
qualities = xls_tab['Qualities']
category_skills = xls_tab['Category_skills']

# %%
# Fill the NaN dates to current timestamp

# Turn all the NaT in a current date and normalize it back to a normal date
now_normalized = pd.Timestamp.now().normalize()
now_month = now_normalized.strftime('%B')
now_year = now_normalized.year

def set_current_time_nan_date(dates):
    return pd.to_datetime(dates).fillna(pd.Timestamp.now().normalize())

# %%
# I normalize all the date in the experiences table
experiences['start_date'] = pd.to_datetime(experiences['start_date'])
experiences['end_date'] = pd.to_datetime(experiences['end_date'])

# Empty the null dates with the current timestamp normalized
experiences['start_date'] = set_current_time_nan_date(experiences['start_date'])
experiences['end_date'] = set_current_time_nan_date(experiences['end_date'])

experiences['start_month'] = pd.to_datetime(experiences['start_date']).dt.month_name()
experiences['start_year'] = pd.to_datetime(experiences['start_date']).dt.year
experiences['end_month'] = pd.to_datetime(experiences['end_date']).dt.month_name()
experiences['end_year'] = pd.to_datetime(experiences['end_date']).dt.year

# %%
# Just the year is stored in the education section, no need to convert in datetime
# But need to convert in 'int' instead of a 'float' to remove the ',0'
educations['year_end'] = educations['year_end'].astype('Int64')
educations['degree_id'] = educations['degree_id'].astype('Int64')

# %%
# Search a words in a dataf
def search_word_column_field(dataframe):
    return [col for col in dataframe.columns if re.search('_id$|^id_|id', col)]

# %%
# Put the current timestamp to 'Present'

# %% [markdown]
# PERSONAL INFORMATIONS SECTION

# %%
# personal infos
me_locations = me.merge(locations, 
                        left_on='location_id',
                        right_on='id',
                        suffixes=('', '_location'))

# %%
name = f'{me_locations['first_name'].iloc[0]} {me_locations['last_name'].iloc[0]}\n'
driving_licence = 'Yes' if me_locations.loc[0, 'driving_licence'] == 1 else 'No'
driving_licence = f'Driving licence : {driving_licence}\n'
phone = f'📞 +33{me_locations['phone'].iloc[0]}\n'
email = f'✉️ {me_locations['email'].iloc[0]}\n'
localisation  = f'📍 {me_locations['city'].iloc[0]}, {me_locations['country'].iloc[0]}'
personal_info = name + driving_licence + phone + email + localisation + '\n\n'

# %% [markdown]
# QUALITIES SECTION

# %%
# display the qualities 
quality_str = 'QUALITIES \n'
quality_str += '----------------------------------------------------------------------------- \n\n'
quality_str += ' | '.join(qualities['name'])
quality_str += '\n\n'

# %% [markdown]
# SKILLS & CATEGORIES

# %%
# retrieve the infos from category and skills
skills_categories_merged = skills.merge(category_skills, 
                                        left_on='category_id',
                                       right_on='id',
                                       suffixes=('', '_category'))

# %%
skills_str = 'SKILLS \n'
skills_str += '----------------------------------------------------------------------------- \n\n'

# Create a new column to concatenate all the skills with their level
skills_categories_merged['skill_with_level'] = skills_categories_merged.apply(
    lambda row: f'{row['name']} ({row['level']})', axis=1
)

# group by category to display in a better view
grouped_skills_category = skills_categories_merged.groupby('name_category', as_index = False).agg({
    'skill_with_level': lambda x: ', '.join(x)
})

for index, skill in grouped_skills_category.iterrows():
    skills_str += f'{skill['name_category']} : {skill['skill_with_level']}\n\n'
skills_str += '\n'

# %% [markdown]
# EXPERIENCES SECTION

# %%
# Merged all the relevant tables to display the experiences
skills_skillexperiences = skill_experiences.merge(skills_categories_merged, 
                                       left_on='skill_id', 
                                       right_on='id',
                                                 suffixes=('','_skill'))
experience_skills = skills_skillexperiences.merge(experiences, 
                                                  left_on='experience_id', 
                                                  right_on='id', 
                                                  suffixes=('','_experience'))
experience_skills_companies = experience_skills.merge(companies, 
                                                      left_on='company_id', 
                                                      right_on='id',
                                                     suffixes=('', '_company'))
experience_skills_companies_contracts = experience_skills_companies.merge(contracts,
                                                               left_on ='contract_id',
                                                               right_on = 'id',
                                                               suffixes=('', '_contract'))
experiences_merged = experience_skills_companies_contracts.merge(locations, 
                                                left_on='location_id', 
                                                right_on='id',
                                               suffixes=('', '_location'))

# %%
fields_experiences_contain_id = search_word_column_field(experiences_merged)
experiences_merged = experiences_merged.drop(columns=fields_experiences_contain_id)

# %%
# rename the fields that are ambiguous
experiences_merged = experiences_merged.rename(columns={'name' : 'skill'})
experiences_merged.head()
# Out:
#                 skill         level                       name_category  \
# 0          Management  Intermediate  IT project and Product Management
# 1           Marketing  Intermediate         Marketing and Communication
# 2  Project Management  Intermediate  IT project and Product Management
# 3    Customer Service  Intermediate         Marketing and Communication
# 4       Communication      Advanced         Marketing and Communication
#
#                     skill_with_level start_date   end_date  \
# 0          Management (Intermediate) 2015-04-01 2015-09-01
# 1           Marketing (Intermediate) 2015-04-01 2015-09-01
# 2  Project Management (Intermediate) 2015-04-01 2015-09-01
# 3    Customer Service (Intermediate) 2015-04-01 2015-09-01
# 4           Communication (Advanced) 2015-04-01 2015-09-01
#
#                       job_title  \
# 0  tourism production assistant
# 1  tourism production assistant
# 2  tourism production assistant
# 3  tourism production assistant
# 4  tourism production assistant
#
#                                             job_desc start_month  start_year  \
# 0  In collaboration with the head "Group' departm...       April        2015
# 1  In collaboration with the head "Group' departm...       April        2015
# 2  In collaboration with the head "Group' departm...       April        2015
# 3  In collaboration with the head "Group' departm...       April        2015
# 4  In collaboration with the head "Group' departm...       April        2015
#
#    end_month  end_year            name_company industry            type city  \
# 0  September      2015  Magic Travel Group LLC  Tourism  Work placement  NYC
# 1  September      2015  Magic Travel Group LLC  Tourism  Work placement  NYC
# 2  September      2015  Magic Travel Group LLC  Tourism  Work placement  NYC
# 3  September      2015  Magic Travel Group LLC  Tourism  Work placement  NYC
# 4  September      2015  Magic Travel Group LLC  Tourism  Work placement  NYC
#
#   country
# 0     USA
# 1     USA
# 2     USA
# 3     USA
# 4     USA

# %%
# Display all the experiences

# All rows are duplicated because for each skill associated with an experience
# Objective : group all the experiences and concatenate all skills per experience
# That's why I filter those columns to not taking in account when grouping
columns_to_take = [col for col in experiences_merged.columns if col not in[
    'skill', 'name_category', 'skill_with_level', 'level']]

grouped_experiences = experiences_merged.groupby(columns_to_take, as_index=False).agg({
    'skill': lambda x: ', '.join(sorted(set(x)))  # Combine skill names into one string
})
grouped_experiences = grouped_experiences.sort_values('start_date', ascending=False)
grouped_experiences.head()
# Out:
#    start_date   end_date                                          job_title  \
# 10 2025-06-01 2025-07-28                         Seller in an organic store
# 9  2022-08-01 2025-07-28  Health therapist : digestion, sleep management...
# 8  2020-03-01 2021-02-01                      Working holiday Visa in Japan
# 7  2019-09-01 2019-11-01                         Seller in an organic store
# 6  2019-01-01 2019-07-01                             Angular/java developer
#
#                                              job_desc start_month  start_year  \
# 10  I worked again as organic store assitant to ke...        June        2025
# 9   I built my own business in the health industry...      August        2022
# 8   I had a dream coming to Japan for one year thr...       March        2020
# 7   I worked as organic shop assistant because I w...   September        2019
# 6   Developing a whole web application for a web-b...     January        2019
#
#    end_month  end_year   name_company            industry  \
# 10      July      2025  La Vie Claire            Organic
# 9       July      2025         Myself              Health
# 8   February      2021         Myself  Language teaching
# 7   November      2019  La Vie Claire            Organic
# 6       July      2019            CGI                SSII
#
#                    type   city country  \
# 10  Short-term contract   Lyon  France
# 9             Freelance   Lyon  France
# 8                 Other  Osaka   Japan
# 7   Short-term contract   Lyon  France
# 6    Long-term contract   Lyon  France
#
#                                                 skill
# 10  Communication, Management, Marketing, Project ...
# 9   Communication, Management, Marketing, Project ...
# 8                            English, French, Spanish
# 7   Communication, Communication marketing, Custom...
# 6         PostgreSQL, Project Management, Python, SQL

# %%
# displaying the experiences as we can see in a resume
experience = 'EXPERIENCES \n'
experience += '----------------------------------------------------------------------------- \n\n'
for index, items in grouped_experiences.iterrows():
    # I check if the date is equal to current timestamp to replace by present
    if items['end_month']==now_month and items['end_year']==now_year:
        items['end_month'], items['end_year'] = 'Present', ''
    
    dates = '📅 {} - {} \n'.format(
        str(items['start_month']) + ' ' + str(items['start_year']), 
        str(items['end_month'])+ ' ' + str(items['end_year']))
    job_title = '** {} '.format(items['job_title'])
    company = f'{items['name_company']} - {items['city']}, {items['country']} ** '
    contract_type = f'({items['type']})\n'
    job_description = '{} \n'.format(items['job_desc'])
    skill_got = 'Skills acquired: {} \n\n'.format(items['skill'])
    experience += dates + job_title + company + contract_type + job_description + skill_got + '\n'

# %% [markdown]
# EDUCATION SECTION

# %%
# merge with degree and school with location
educations_degree = educations.merge(degrees,
                                     left_on='degree_id', 
                                     right_on='id',
                                     suffixes=('','_degree')) 
educations_degrees_schools = educations_degree.merge(schools,
                                                     left_on='school_id', 
                                                     right_on='id',
                                                     suffixes=('', '_school'))
educations_merged = educations_degrees_schools.merge(locations,
                                                     left_on='location_id',
                                                     right_on='id',
                                                    suffixes=('', '_location'))

# %%
# Search and remove the columns with id
fields_educations_contain_id = search_word_column_field(educations_merged)
educations_merged = educations_merged.drop(columns=fields_educations_contain_id)

# %%
educations_merged = educations_merged.sort_values('year_start', ascending=False)

# %%
# displaying the experiences as we can see in a resume
education_str = 'EDUCATION \n'
education_str += '----------------------------------------------------------------------------- \n\n'
for index, items in educations_merged.iterrows():
    if pd.isna(items['year_end']):
            items['year_end'] = 'Present'
    dates = '📅 {} - {} \n'.format(
        str(items['year_start']), str(items['year_end']))
    degree = '** {} - {} **\n'.format(
        items['type'], 
        items['description'])
    school = '{} - {} - {} - {}\n\n'.format(
        items['name'], 
        items['type_school'], 
        items['city'],
        items['country'])
    education += dates + degree + school + '\n'

# %% [markdown]
# LEISURES

# %%
# displaying the experiences as we can see in a resume
leisure_str = 'LEISURES \n'
leisure_str += '----------------------------------------------------------------------------- \n\n'
leisure_str += ' | '.join(leisures['name'])
leisure_str += '\n\n'

# %% [markdown]
# WHOLE RESUME

# %%
whole_resume = personal_info + quality_str + skills_str + experience + education_str + leisure_str
print(whole_resume)
# Out:
# Cédric BERTHEZENE
# Driving licence : Yes
# 📞 +33671927780
# ✉️ cedric.berthezene@gmail.com
# 📍 Lyon, France
#
# QUALITIES
# -----------------------------------------------------------------------------
#
# Autonomous | Flexible | Dynamique | Trustworthy | Persevering | Strong-willed
#
# SKILLS
# -----------------------------------------------------------------------------
#
# Data analysis and Business Intelligence : Business Strategy (Intermediate), Sales strategy (Intermediate)
#
# Databases and Data Management : Database management (Intermediate), Database queries (Intermediate), Database design  (Intermediate), Jupyter (Intermediate), PostgreSQL (Intermediate)
#
# IT project and Product Management  : Management (Intermediate), Project Management (Intermediate)
#
# Languages : Spanish (Intermediate), English (Advanced)
#
# Marketing and Communication : Marketing Strategy (Intermediate), Marketing Communications (Intermediate), Marketing (Intermediate), Social Media (Intermediate), Customer Service (Intermediate), Marketing (Intermediate), Communication (Advanced), Event Management (Intermediate), Communication marketing (Intermediate)
#
# Office and Productivity tools : French (Native), Microsoft Office (Intermediate), Microsoft Excel (Intermediate), PowerPoint (Intermediate)
#
# Programming and scripting : Python (Intermediate), SQL (Intermediate), PHP (Intermediate), HTML5 (Advanced), CSS3 (Intermediate )
#
#
# EXPERIENCES
# -----------------------------------------------------------------------------
#
# 📅 June 2025 - Present
# ** Seller in an organic store La Vie Claire - Lyon, France ** (Short-term contract)
# I worked again as organic store assitant to keep preparing my natural health therapist project
# Skills acquired: Communication, Management, Marketing, Project Management
#
#
# 📅 August 2022 - Present
# ** Health therapist : digestion, sleep management, stress management Myself - Lyon, France ** (Freelance)
# I built my own business in the health industry as natural health therapist to help people improving their health, daily routine and way of taking care of their health
# Skills acquired: Communication, Management, Marketing, Project Management
#
#
# 📅 March 2020 - February 2021
# ** Working holiday Visa in Japan Myself - Osaka, Japan ** (Other)
# I had a dream coming to Japan for one year through a working holiday visa to fulfill my dream. And I worked as langugage tutor and in the manufacture industry
# Skills acquired: English, French, Spanish
#
#
# 📅 September 2019 - November 2019
# ** Seller in an organic store La Vie Claire - Lyon, France ** (Short-term contract)
# I worked as organic shop assistant because I wanted to prepare for a new project 'natural health assistant'
# Skills acquired: Communication, Communication marketing, Customer Service, Management, Marketing, Marketing Strategy, Microsoft Excel, Microsoft Office, PowerPoint, Project Management, Sales strategy, Social Media
#
#
# 📅 January 2019 - July 2019
# ** Angular/java developer CGI - Lyon, France ** (Long-term contract)
# Developing a whole web application for a web-based wealth management project using Angular and Java
# Skills acquired: PostgreSQL, Project Management, Python, SQL
#
#
# 📅 September 2018 - December 2018
# ** N2 team  support CGI - Lyon, France ** (Work-study program)
# Included in a large team to solving SQL / .Net issues, I was in charge of :
# - Analysing issues reported by the supermarket team
# - Implementing the solution and communicating the fixes with another team
# - Integrating the solution after validation
# Skills acquired: Jupyter, Project Management, SQL
#
#
# 📅 May 2018 - September 2018
# ** BDOC consultant  CGI - Lyon, France ** (Work-study program)
# Included in a team of 4 and for the same banking project, I was in charge of :
# - participating in the management and optimization of the document generation process
# - automating and maintaining ocument workflows unsing BDOC
# - Collaborating with functional and technical teams to ensure quality deliverables
# - Analaysing and resolving anomalies to ensure service continuity
# Skills acquired: Communication, Database design , Project Management
#
#
# 📅 December 2017 - April 2018
# ** Java developper CGI - Lyon, France ** (Work-study program)
# Desining and Developing web services for a bank project
# Skills acquired: Database queries, PostgreSQL, Python, SQL
#
#
# 📅 May 2017 - June 2017
# ** Web integrator 3VOOIE - Lyon, France ** (Work placement)
# Assisting the project manager to integrate correctly all the web projects using HTML5 / LESS / SASS / CSS3 and content management  systems (CMS) like Contao or Magento for online sales companies
# Skills acquired: CSS3, Communication, HTML5
#
#
# 📅 June 2016 - July 2016
# ** Web developper and web project assistant Altibus - Chambéry, France ** (Work placement)
# Within the web departement, my tasks included :
# - Developing an on-demand transport module in responsive design using HTML5/CSS3/OOP PHP/Jquery
# - Assisting the project manager in her daily-tasks
# Skills acquired: CSS3, Communication, HTML5, PHP, Python
#
#
# 📅 April 2015 - September 2015
# ** tourism production assistant Magic Travel Group LLC - NYC, USA ** (Work placement)
# In collaboration with the head "Group' department, I was in charge of :
# - researching and booking the various components of the trip (accomodations, transports, meals and attractions)
# - ensuring the smooth running of the trip (phone support and itinerary verification)
# - representing the agency at tourist and cultural events organized  in NYC
# Skills acquired: Communication, Customer Service, Event Management, Management, Marketing, Project Management
#
#
# EDUCATION
# -----------------------------------------------------------------------------
#
# 📅 2025 - Present
# ** Bachelor  - Data analyst **
# OpenClassrooms - Private school - Lyon - France
#
#
# 📅 2021 - 2022
# ** Other  - Application web developement **
# L'Arbre Rouge - Ecole professionnelle de naturopathie - Private school - Lyon - France
#
#
# 📅 2016 - 2017
# ** 2-year technical degree - Web integration **
# Ecole Aries - Private school - Lyon - France
#
#
# 📅 2013 - 2015
# ** Master - Tourism management **
# IAE Savoie Mont-Blanc - University - Chambéry - France
#
#
# 📅 2009 - 2012
# ** Bachelor  - Sales and management  **
# Ecole de Gestion et de Commerce Drôme-Ardèche - Private school - Valence - France
#
#
# LEISURES
# -----------------------------------------------------------------------------
#
# Travelling | Soccer | Tennis
